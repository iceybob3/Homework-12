# %%
import sqlite3
import pandas as pd

# %%
connection = sqlite3.connect('books.db')

# %% [markdown]
# pd.options.display.max_columns = 10

# %% [markdown]
# authors = pd.read_sql(
# SELECT last FROM authors ORDER BY last DESC
# , connection)<br>
# print(authors)<br>
# print()<br>
# titles = pd.read_sql('SELECT title FROM titles ORDER BY title ASC', connection)<br>
# print(titles)<br>
# print()<br>
# ld = pd.read_sql(
# SELECT title, copyright, isbn FROM authors INNER JOIN titles

# %% [markdown]
#                     WHERE last LIKE 'W%' ORDER BY title  ASC
# , connection)<br>
# print(wald)<br>
# print()<br>
# cursor = connection.cursor()<br>
# rsor = cursor.execute(
# INSERT INTO authors (first, last, id) VALUES ('Sue', 'Red', '6')
# )

# %% [markdown]
# authors = pd.read_sql(
# SELECT last FROM authors ORDER BY last DESC
# , connection)<br>
# print(authors)<br>
# rsor = cursor.execute(
# INSERT INTO author_ISBN (id, isbn) VALUES ('6', '0385934517')
# )

# %% [markdown]
# cursor = cursor.execute(
# INSERT INTO titles (isbn, title, edition, copyright) <br>
#                          VALUES ('0385934517', 'New Book', '1', '2023')
# )

# %% [markdown]
# all_ISBN = pd.read_sql(
# SELECT * FROM author_ISBN
# , connection)<br>
# print(all_ISBN)<br>
# l_author = pd.read_sql(
# SELECT * FROM authors
# , connection)

# %%
print(all_author)

# %% [markdown]
# all_title = pd.read_sql(
# SELECT * FROM titles
# , connection)<br>
# print(all_title)

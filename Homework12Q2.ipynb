# %%
import sqlite3

# %%
connection = sqlite3.connect('books.db')
cursor = connection.cursor()

# %% [markdown]
# info = cursor.execute(
# SELECT * FROM titles
# )<br>
# for i in range(0, 4):<br>
#     print(info.description[i][0], end=' ')<br>
#     if i == 0:<br>
#         print(end='        ')<br>
#     elif i == 1:<br>
#         print(end='                             ')<br>
#     elif i == 2:<br>
#         print(end='    ')<br>
# print()<br>
# for entry in info.fetchall():<br>
#     for i in range(0, 4):<br>
#         print(entry[i], end='   ')<br>
#         maxSize = 32<br>
#         size = len(str(entry[i]))<br>
#         if i == 1:<br>
#             if size < maxSize:<br>
#                 for j in range(size, maxSize):<br>
#                     print(end=' ')<br>
#         if i == 2:<br>
#             if len(str(entry[i])) == 1:<br>
#                 print(end='        ')<br>
#             else:<br>
#                 print(end='       ')<br>
#     print()
